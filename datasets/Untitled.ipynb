# %%
import pandas as pd
# Out:
# /usr/local/Anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/local/Anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
csv = pd.read_csv('USvideos.csv')
print(len(csv))
# Out:
# 40949

# %%
csv
# Out:
#           video_id trending_date  \
# 0      2kyS6SvSYSE      17.14.11
# 1      1ZAPwfrtAFY      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      puqaWrEC7tY      17.14.11
# 4      d380meD0W0M      17.14.11
# 5      gHZ1Qz0KiKM      17.14.11
# 6      39idVpFF7NQ      17.14.11
# 7      nc99ccSXST0      17.14.11
# 8      jr9QtXwC9vc      17.14.11
# 9      TUmyygCMMGA      17.14.11
# 10     9wRQljFNDW8      17.14.11
# 11     VifQlJit6A0      17.14.11
# 12     5E4ZBSInqUU      17.14.11
# 13     GgVmn66oK_A      17.14.11
# 14     TaTleo4cOs8      17.14.11
# 15     kgaO45SyaO4      17.14.11
# 16     ZAQs-ctOqXQ      17.14.11
# 17     YVfyYrEmzgM      17.14.11
# 18     eNSN6qet1kE      17.14.11
# 19     B5HORANmzHw      17.14.11
# 20     vU14JY3x81A      17.14.11
# 21     6VhU_T463sU      17.14.11
# 22     _-aDHxoblr4      17.14.11
# 23     JBZTZZAcFTw      17.14.11
# 24     lZ68j2J_GOM      17.14.11
# 25     dRpNZV18N_g      17.14.11
# 26     fcVjitaM3LY      17.14.11
# ...

# %%
csv = csv.sort_values(by=['views'])

# %%
csv
# Out:
#           video_id trending_date  \
# 14335  y6KYFcta4SE      18.26.01
# 14563  y6KYFcta4SE      18.27.01
# 14782  y6KYFcta4SE      18.28.01
# 14531  dQMZLXaa1L8      18.27.01
# 546    -JVITToppE0      17.16.11
# 777    -JVITToppE0      17.17.11
# 14750  dQMZLXaa1L8      18.28.01
# 14984  dQMZLXaa1L8      18.29.01
# 12716  zeQaJGkFyqQ      18.18.01
# 160    qg0GdM60syI      17.14.11
# 11103  JNv4w6DFoYs      18.08.01
# 14816  S_HixQBiVH0      18.29.01
# 12961  tKX8nUCSBjM      18.19.01
# 13187  tKX8nUCSBjM      18.20.01
# 13398  tKX8nUCSBjM      18.21.01
# 11710  TKMXw1YI5S4      18.13.01
# 11329  JNv4w6DFoYs      18.09.01
# 1114   g3VgrgV3kFk      17.19.11
# 11924  TKMXw1YI5S4      18.14.01
# 10902  s_FAjI51LPU      18.07.01
# 42     NZFhMSgbKKM      17.14.11
# 12156  TKMXw1YI5S4      18.15.01
# 13145  jiP82WVx6mM      18.20.01
# 10704  Wwyxaow1wWg      18.06.01
# 12371  TKMXw1YI5S4      18.16.01
# 1339   g3VgrgV3kFk      17.20.11
# 11131  s_FAjI51LPU      18.08.01
# ...

# %%
csv.index
# Out:
# Int64Index([14335, 14563, 14782, 14531,   546,   777, 14750, 14984, 12716,
#               160,
#             ...
#             36710, 36913, 37123, 37333, 37531, 37730, 37935, 38146, 38345,
#             38547],
#            dtype='int64', length=40949)

# %%
max(csv.index)
# Out:
# 40948

# %%
csv.index = range(40949)

# %%
csv
# Out:
#           video_id trending_date  \
# 0      y6KYFcta4SE      18.26.01
# 1      y6KYFcta4SE      18.27.01
# 2      y6KYFcta4SE      18.28.01
# 3      dQMZLXaa1L8      18.27.01
# 4      -JVITToppE0      17.16.11
# 5      -JVITToppE0      17.17.11
# 6      dQMZLXaa1L8      18.28.01
# 7      dQMZLXaa1L8      18.29.01
# 8      zeQaJGkFyqQ      18.18.01
# 9      qg0GdM60syI      17.14.11
# 10     JNv4w6DFoYs      18.08.01
# 11     S_HixQBiVH0      18.29.01
# 12     tKX8nUCSBjM      18.19.01
# 13     tKX8nUCSBjM      18.20.01
# 14     tKX8nUCSBjM      18.21.01
# 15     TKMXw1YI5S4      18.13.01
# 16     JNv4w6DFoYs      18.09.01
# 17     g3VgrgV3kFk      17.19.11
# 18     TKMXw1YI5S4      18.14.01
# 19     s_FAjI51LPU      18.07.01
# 20     NZFhMSgbKKM      17.14.11
# 21     TKMXw1YI5S4      18.15.01
# 22     jiP82WVx6mM      18.20.01
# 23     Wwyxaow1wWg      18.06.01
# 24     TKMXw1YI5S4      18.16.01
# 25     g3VgrgV3kFk      17.20.11
# 26     s_FAjI51LPU      18.08.01
# ...
