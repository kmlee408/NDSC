# %%
import Preprocessing
# Out:
# /usr/local/Anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/local/Anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
import os
import sys

# %%
_fpath = os.path.abspath('../datasets') + '/GBvideos.csv'
_multip_num = 30

# %%
_durations_and_errors = Preprocessing.get_video_len(_fpath, _multip_num)
# Out:
# Process Started
# Process Started
# Process Started
# Process Started
# Process Started
# Process Started
# Process Started
# Process Started
# Process Started
# Process Started
# Process Started
# Process Started
# Process Started
# Process Started
# Process Started
# Process Started
# Process Started
# Process Started
# Process Started
# Process Started
# Process Started
# Process Started
# Process Started
# Process Started
# Process Started
# Process Started
# Process Started
# Process Started
# Process Started
# Process Started
# PT14M45S
# PT34M19S
# PT2M11S
# PT1M56S
# PT1M1S
# PT5M31S
# PT8M44S
# PT8M22S
# PT3M47S
# PT2M21S
# PT31M16S
# PT20M23S
# PT5M10S
# PT12M4S
# PT3M49S
# PT11M33S
# PT5M34S
# PT19M25S
# PT2M26S
# PT4M54S
# PT2M16S
# PT13M31S
# PT13M21S
# PT1M57S
# PT9M5S
# PT3H7M21S
# PT3M48S
# PT4M10S
# PT4M50S
# PT3M11S
# PT2M27S
# PT1M23S
# PT2M46S
# PT12M38S
# PT9M52S
# PT9M44S
# PT4M
# PT13S
# -1
# PT4M50S
# PT2M55S
# PT46M34S
# PT13M55S
# PT4M8S
# PT3M40S
# PT8M8S
# ...

# %%
_durations_and_errors
# Out:
# (0          131
#  1            0
#  2          305
#  3          158
#  4            0
#  5         1013
#  6          280
#  7         2214
#  8          146
#  9          238
#  10         591
#  11          53
#  12         162
#  13        1060
#  14          87
#  15         104
#  16         340
#  17         217
#  18         360
#  19         186
#  20         898
#  21         378
#  22         192
#  23         220
#  24         234
#  25         454
#  26         516
#  27         787
#  28         241
#  29         146
#           ...
#  38886    10372
#  38887     1104
#  38888      169
#  38889     1119
#  38890      314
#  38891      262
#  38892      180
#  38893      200
#  38894      141
#  38895      196
#  38896      329
#  38897      147
#  38898      196
#  38899      233
#  38900      235
#  38901      232
#  38902      231
#  38903      187
#  38904      291
#  38905      231
#  38906      217
#  38907      217
#  38908      351
#  38909      201
# ...

# %%
type(_durations_and_errors)
# Out:
# tuple

# %%
import pandas as pd

# %%
_durations = pd.Series(_durations_and_errors[0])

# %%
csv = pd.read_csv('/home/jin/Github/Personal/NDSC/datasets/GBvideos.csv')

# %%
pd.Series(_durations).to_csv('./germany.csv')

# %%
_durations_and_errors[1]
# Out:
# []
