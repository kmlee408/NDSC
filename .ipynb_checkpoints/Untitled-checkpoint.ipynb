# %%
import os
import sys
import time
import multiprocessing as mp
_sys_add_path = os.path.abspath('./YT_api')
sys.path.insert(1,_sys_add_path)

import pandas as pd

import YouTube

# %%
fpath = './datasets/USvideos.csv'
_dt = pd.read_csv(fpath)

_vids = _dt['video_id']
l_vids = len(_vids)


yt = YouTube.YouTube('AIzaSyDdPiRW0lXGtY_s188gr6tIZ8WY_ZqAglM')

# %%
def runner_get_duration(vid_list):
    _duration = [ yt.get_duration(vid) for vid in vid_list ]
    return _duration

# %%
_st = time.time()


result = []
try:
    MP = 40
    pool = mp.Pool(processes=MP)

    _div = int(l_vids / MP) + 1 #2000
    #_parts = int(l_vids / _div) #_div개씩, parts = 20개

    for idx in range(MP):# 20번 반복
        _s = idx*_div
        _e = _s + _div

        lst = _vids[_s:_e]
        result.append(pool.apply_async(runner_get_duration, args=(lst,)))
    
except Exception as e:
    print(e)
finally:
    pool.close()
    pool.join()
    
durations = [] #will be list of lists
for rst in result:
    durations.append(rst.get()) #append a list
    
    
_et = time.time()
print('time elapsed : '+str(_et-_st))
# Out:
# PT11M2S
# PT3M38S
# -1
# PT31S
# -1
# PT1M30S
# PT3M6S
# PT6M25S
# PT1M44S
# PT17M4S
# PT3M17S
# PT4M13S
# PT6M39S
# PT3M43S
# PT7M40S
# PT6M52S
# PT11M18S
# PT4M11S
# PT49S
# PT2M58S
# PT9M3S
# PT3M55S
# PT7M13S
# PT3M28S
# PT49M34S
# PT3M24S
# PT7M6S
# PT17S
# PT9M47S
# PT2M9S
# PT2M47S
# PT2M18S
# PT23M2S
# PT5M56S
# PT7M3S
# PT11M34S
# PT3M33S
# PT4M11S
# PT3M15S
# PT3M50S
# PT10M9S
# PT14M4S
# PT3M2S
# PT1M20S
# PT1M42S
# PT18M58S
# PT7M59S
# PT5M16S
# PT1M54S
# PT3M36S
# PT1M57S
# PT1M20S
# PT3M44S
# PT5M53S
# PT4M40S
# PT22S
# PT12M15S
# PT3M23S
# PT23M51S
# PT10M54S
# PT18M15S
# PT5M18S
# PT15M51S
# PT16M19S
# PT5M8S
# PT6M10S
# PT16M11S
# PT1M47S
# PT12M40S
# PT4M20S
# PT3M26S
# PT5M2S
# PT6M52S
# PT9M25S
# PT6M6S
# PT1M46S
# PT6M47S
# PT3M17S
# PT2M15S
# PT1M16S
# PT47S
# PT5M44S
# PT14M18S
# PT5M11S
# PT10M19S
# PT3M33S
# PT6M49S
# PT10M3S
# PT1M1S
# PT4M55S
# PT49S
# PT1M57S
# PT44S
# PT1M52S
# PT3M44S
# PT8M16S
# PT3M33S
# PT16S
# PT9M29S
# PT1M31S
# PT2M46S
# PT3M3S
# ...

# %%
len(durations)
# Out:
# 8
